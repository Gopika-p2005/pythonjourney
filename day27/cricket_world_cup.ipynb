# %%
cricket_world_cup = [
    {"country": "Sri Lanka", "wins": 1, "runners_up": 2, "appearances": 13},
    {"country": "Zimbabwe", "wins": 0, "runners_up": 0, "appearances": 9},
    {"country": "England", "wins": 1, "runners_up": 3, "appearances": 13},
    {"country": "Bangladesh", "wins": 0, "runners_up": 0, "appearances": 7},
    {"country": "Australia", "wins": 6, "runners_up": 2, "appearances": 13},
    {"country": "West Indies", "wins": 2, "runners_up": 1, "appearances": 12},
    {"country": "South Africa", "wins": 0, "runners_up": 0, "appearances": 9},
    {"country": "Pakistan", "wins": 1, "runners_up": 1, "appearances": 13},
    {"country": "New Zealand", "wins": 0, "runners_up": 2, "appearances": 13},
    {"country": "India", "wins": 2, "runners_up": 2, "appearances": 13}
]

# %%
sorted(cricket_world_cup,key=lambda dct:dct["wins"],reverse=True)
# Out:
# [{'country': 'Australia', 'wins': 6, 'runners_up': 2, 'appearances': 13},
#  {'country': 'West Indies', 'wins': 2, 'runners_up': 1, 'appearances': 12},
#  {'country': 'India', 'wins': 2, 'runners_up': 2, 'appearances': 13},
#  {'country': 'Sri Lanka', 'wins': 1, 'runners_up': 2, 'appearances': 13},
#  {'country': 'England', 'wins': 1, 'runners_up': 3, 'appearances': 13},
#  {'country': 'Pakistan', 'wins': 1, 'runners_up': 1, 'appearances': 13},
#  {'country': 'Zimbabwe', 'wins': 0, 'runners_up': 0, 'appearances': 9},
#  {'country': 'Bangladesh', 'wins': 0, 'runners_up': 0, 'appearances': 7},
#  {'country': 'South Africa', 'wins': 0, 'runners_up': 0, 'appearances': 9},
#  {'country': 'New Zealand', 'wins': 0, 'runners_up': 2, 'appearances': 13}]

# %%
srt_wins=sorted(cricket_world_cup,key=lambda lst:lst["wins"],reverse=True)

print(srt_wins)
# Out:
# [{'country': 'Australia', 'wins': 6, 'runners_up': 2, 'appearances': 13}, {'country': 'West Indies', 'wins': 2, 'runners_up': 1, 'appearances': 12}, {'country': 'India', 'wins': 2, 'runners_up': 2, 'appearances': 13}, {'country': 'Sri Lanka', 'wins': 1, 'runners_up': 2, 'appearances': 13}, {'country': 'England', 'wins': 1, 'runners_up': 3, 'appearances': 13}, {'country': 'Pakistan', 'wins': 1, 'runners_up': 1, 'appearances': 13}, {'country': 'Zimbabwe', 'wins': 0, 'runners_up': 0, 'appearances': 9}, {'country': 'Bangladesh', 'wins': 0, 'runners_up': 0, 'appearances': 7}, {'country': 'South Africa', 'wins': 0, 'runners_up': 0, 'appearances': 9}, {'country': 'New Zealand', 'wins': 0, 'runners_up': 2, 'appearances': 13}]

# %%
most_win_team=srt_wins[0]

print(most_win_team)
# Out:
# {'country': 'Australia', 'wins': 6, 'runners_up': 2, 'appearances': 13}

# %%
least_wins=srt_wins[-1]

print(least_wins)
# Out:
# {'country': 'New Zealand', 'wins': 0, 'runners_up': 2, 'appearances': 13}

# %%
teams=[team["country"] for team in cricket_world_cup]

win=[team["wins"] for team in cricket_world_cup]

import matplotlib.pyplot as plt

plt.figure(figsize=[12,8])

plt.bar(teams,win)

plt.show()

# %%
str_appearence=sorted(cricket_world_cup,key= lambda dct:dct["appearances"],reverse=True)

print(str_appearence)
# Out:
# [{'country': 'Sri Lanka', 'wins': 1, 'runners_up': 2, 'appearances': 13}, {'country': 'England', 'wins': 1, 'runners_up': 3, 'appearances': 13}, {'country': 'Australia', 'wins': 6, 'runners_up': 2, 'appearances': 13}, {'country': 'Pakistan', 'wins': 1, 'runners_up': 1, 'appearances': 13}, {'country': 'New Zealand', 'wins': 0, 'runners_up': 2, 'appearances': 13}, {'country': 'India', 'wins': 2, 'runners_up': 2, 'appearances': 13}, {'country': 'West Indies', 'wins': 2, 'runners_up': 1, 'appearances': 12}, {'country': 'Zimbabwe', 'wins': 0, 'runners_up': 0, 'appearances': 9}, {'country': 'South Africa', 'wins': 0, 'runners_up': 0, 'appearances': 9}, {'country': 'Bangladesh', 'wins': 0, 'runners_up': 0, 'appearances': 7}]

# %%
most_apperances=str_appearence[0]

print(most_apperances)
# Out:
# {'country': 'Sri Lanka', 'wins': 1, 'runners_up': 2, 'appearances': 13}

# %%
least_appearances=str_appearence[-1]

print(least_appearances)
# Out:
# {'country': 'Bangladesh', 'wins': 0, 'runners_up': 0, 'appearances': 7}

# %%
teams=[team["country"] for team in cricket_world_cup]

apperarance=[team["appearances"] for team in cricket_world_cup]

import matplotlib.pyplot as plt

plt.figure(figsize=[12,8])

plt.bar(teams,apperarance)

plt.show()

# %%
srt_runners_up=sorted(cricket_world_cup,key=lambda lst:lst["runners_up"],reverse=True)

print(srt_runners_up)
# Out:
# [{'country': 'England', 'wins': 1, 'runners_up': 3, 'appearances': 13}, {'country': 'Sri Lanka', 'wins': 1, 'runners_up': 2, 'appearances': 13}, {'country': 'Australia', 'wins': 6, 'runners_up': 2, 'appearances': 13}, {'country': 'New Zealand', 'wins': 0, 'runners_up': 2, 'appearances': 13}, {'country': 'India', 'wins': 2, 'runners_up': 2, 'appearances': 13}, {'country': 'West Indies', 'wins': 2, 'runners_up': 1, 'appearances': 12}, {'country': 'Pakistan', 'wins': 1, 'runners_up': 1, 'appearances': 13}, {'country': 'Zimbabwe', 'wins': 0, 'runners_up': 0, 'appearances': 9}, {'country': 'Bangladesh', 'wins': 0, 'runners_up': 0, 'appearances': 7}, {'country': 'South Africa', 'wins': 0, 'runners_up': 0, 'appearances': 9}]

# %%
heighest_runner_up=srt_runners_up[0]

print(heighest_runner_up)
# Out:
# {'country': 'England', 'wins': 1, 'runners_up': 3, 'appearances': 13}

# %%
least_runnrs_up=srt_runners_up[-1]

print(least_runnrs_up)
# Out:
# {'country': 'South Africa', 'wins': 0, 'runners_up': 0, 'appearances': 9}

# %%
wins=[team["wins"] for team in cricket_world_cup]

appearances=[team["appearances"] for team in cricket_world_cup]

import matplotlib.pyplot as plt

plt.scatter(appearances,wins)

plt.show()
