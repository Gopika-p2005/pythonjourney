# %%
passengers = [
    {"name": "Braund, Mr. Owen Harris", "survived": 0, "pclass": 3, "sex": "male", "age": 22, "fare": 7.25},
    {"name": "Cumings, Mrs. John Bradley (Florence Briggs Thayer)", "survived": 1, "pclass": 1, "sex": "female", "age": 38, "fare": 71.28},
    {"name": "Heikkinen, Miss. Laina", "survived": 1, "pclass": 3, "sex": "female", "age": 26, "fare": 7.92},
    {"name": "Futrelle, Mrs. Jacques Heath (Lily May Peel)", "survived": 1, "pclass": 1, "sex": "female", "age": 35, "fare": 53.10},
    {"name": "Allen, Mr. William Henry", "survived": 0, "pclass": 3, "sex": "male", "age": 35, "fare": 8.05},
    {"name": "McCarthy, Mr. Timothy J", "survived": 0, "pclass": 1, "sex": "male", "age": 54, "fare": 51.86},
    {"name": "Palsson, Master. Gosta Leonard", "survived": 0, "pclass": 3, "sex": "male", "age": 2, "fare": 21.07},
    {"name": "Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)", "survived": 1, "pclass": 3, "sex": "female", "age": 27, "fare": 11.13},
    {"name": "Nasser, Mrs. Nicholas (Adele Achem)", "survived": 1, "pclass": 2, "sex": "female", "age": 14, "fare": 30.07},
    {"name": "Sandstrom, Miss. Marguerite Rut", "survived": 1, "pclass": 3, "sex": "female", "age": 4, "fare": 16.70},
    {"name": "Bonnell, Miss. Elizabeth", "survived": 1, "pclass": 1, "sex": "female", "age": 58, "fare": 26.55},
    {"name": "Saundercock, Mr. William Henry", "survived": 0, "pclass": 3, "sex": "male", "age": 20, "fare": 8.05},
    {"name": "Andersson, Mr. Anders Johan", "survived": 0, "pclass": 3, "sex": "male", "age": 39, "fare": 31.27},
    {"name": "Vestrom, Miss. Hulda Amanda Adolfina", "survived": 0, "pclass": 3, "sex": "female", "age": 14, "fare": 7.85},
    {"name": "Hewlett, Mrs. (Mary D Kingcome) ", "survived": 1, "pclass": 2, "sex": "female", "age": 55, "fare": 16.00},
    {"name": "Rice, Master. Eugene", "survived": 0, "pclass": 3, "sex": "male", "age": 2, "fare": 29.12},
    {"name": "Williams, Mr. Charles Eugene", "survived": 1, "pclass": 2, "sex": "male", "age": 23, "fare": 13.00},
    {"name": "Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)", "survived": 0, "pclass": 3, "sex": "female", "age": 31, "fare": 18.00},
    {"name": "Masselmani, Mrs. Fatima", "survived": 1, "pclass": 3, "sex": "female", "age": 22, "fare": 7.22},
    {"name": "Fynney, Mr. Joseph J", "survived": 0, "pclass": 2, "sex": "male", "age": 35, "fare": 26.00},
    {"name": "Beesley, Mr. Lawrence", "survived": 1, "pclass": 2, "sex": "male", "age": 34, "fare": 13.00},
    {"name": "McGowan, Miss. Anna 'Annie'", "survived": 1, "pclass": 3, "sex": "female", "age": 15, "fare": 8.02},
    {"name": "Sloper, Mr. William Thompson", "survived": 1, "pclass": 1, "sex": "male", "age": 28, "fare": 35.50},
    {"name": "Palsson, Miss. Torborg Danira", "survived": 0, "pclass": 3, "sex": "female", "age": 8, "fare": 21.07},
    {"name": "Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)", "survived": 1, "pclass": 3, "sex": "female", "age": 38, "fare": 31.39},
    {"name": "Emir, Mr. Farred Chehab", "survived": 0, "pclass": 3, "sex": "male", "age": 26, "fare": 7.23},
    {"name": "Fortune, Mr. Charles Alexander", "survived": 0, "pclass": 1, "sex": "male", "age": 19, "fare": 263.00},
    {"name": "O'Dwyer, Miss. Ellen 'Nellie'", "survived": 1, "pclass": 3, "sex": "female", "age": 24, "fare": 7.88},
    {"name": "Todoroff, Mr. Lalio", "survived": 0, "pclass": 3, "sex": "male", "age": 23, "fare": 7.90},
    {"name": "Uruchurtu, Don. Manuel E", "survived": 0, "pclass": 1, "sex": "male", "age": 40, "fare": 27.72},
    {"name": "Spencer, Mrs. William Augustus (Marie Eugenie)", "survived": 1, "pclass": 1, "sex": "female", "age": 48, "fare": 146.52},
    {"name": "Glynn, Miss. Mary Agatha", "survived": 1, "pclass": 3, "sex": "female", "age": 19, "fare": 7.75},
    {"name": "Wheadon, Mr. Edward H", "survived": 0, "pclass": 2, "sex": "male", "age": 66, "fare": 10.50},
    {"name": "Meyer, Mr. Edgar Joseph", "survived": 0, "pclass": 1, "sex": "male", "age": 28, "fare": 82.17},
    {"name": "Holverson, Mr. Alexander Oskar", "survived": 0, "pclass": 1, "sex": "male", "age": 42, "fare": 52.00},
    {"name": "Mamee, Mr. Hanna", "survived": 1, "pclass": 3, "sex": "male", "age": 20, "fare": 7.23},
    {"name": "Cann, Mr. Ernest Charles", "survived": 0, "pclass": 2, "sex": "male", "age": 21, "fare": 10.50},
    {"name": "Vander Planke, Miss. Augusta Maria", "survived": 0, "pclass": 3, "sex": "female", "age": 18, "fare": 18.00},
    {"name": "Nicola-Yarred, Miss. Jamila", "survived": 1, "pclass": 3, "sex": "female", "age": 14, "fare": 11.24},
    {"name": "Ahlin, Mrs. Johan (Johanna Persdotter Larsson)", "survived": 0, "pclass": 3, "sex": "female", "age": 40, "fare": 9.48},
    {"name": "Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)", "survived": 0, "pclass": 2, "sex": "female", "age": 27, "fare": 21.00},
    {"name": "Laroche, Miss. Simonne Marie Anne Andree", "survived": 1, "pclass": 2, "sex": "female", "age": 3, "fare": 41.58},
    {"name": "Devaney, Miss. Margaret Delia", "survived": 1, "pclass": 3, "sex": "female", "age": 19, "fare": 7.88},
    {"name": "Arnold-Franchi, Mrs. Josef (Josefine Franchi)", "survived": 0, "pclass": 3, "sex": "female", "age": 18, "fare": 17.80},
    {"name": "Panula, Master. Juha Niilo", "survived": 0, "pclass": 3, "sex": "male", "age": 7, "fare": 39.69},
    {"name": "Nosworthy, Mr. Richard Cater", "survived": 0, "pclass": 3, "sex": "male", "age": 21, "fare": 7.80},
    {"name": "Harper, Mrs. Henry Sleeper (Myna Haxtun)", "survived": 1, "pclass": 1, "sex": "female", "age": 49, "fare": 76.73},
    {"name": "Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)", "survived": 1, "pclass": 2, "sex": "female", "age": 29, "fare": 26.00},
    {"name": "Ostby, Mr. Engelhart Cornelius", "survived": 0, "pclass": 1, "sex": "male", "age": 65, "fare": 61.98},
    {"name": "Rugg, Miss. Emily", "survived": 1, "pclass": 2, "sex": "female", "age": 21, "fare": 10.50},
    {"name": "Novel, Mr. Mansouer", "survived": 0, "pclass": 3, "sex": "male", "age": 28, "fare": 7.23},
    {"name": "West, Miss. Constance Mirium", "survived": 1, "pclass": 2, "sex": "female", "age": 5, "fare": 27.75},
    {"name": "Goodwin, Master. William Frederick", "survived": 0, "pclass": 3, "sex": "male", "age": 11, "fare": 46.90},
    {"name": "Sirayanian, Mr. Orsen", "survived": 0, "pclass": 3, "sex": "male", "age": 22, "fare": 7.23},
    {"name": "Icard, Miss. Amelie", "survived": 1, "pclass": 1, "sex": "female", "age": 38, "fare": 80.00},
    {"name": "Harris, Mr. Henry Birkhardt", "survived": 0, "pclass": 1, "sex": "male", "age": 45, "fare": 83.47},
    {"name": "Skoog, Master. Harald", "survived": 0, "pclass": 3, "sex": "male", "age": 4, "fare": 27.90},
    {"name": "Stewart, Mr. Albert A", "survived": 0, "pclass": 1, "sex": "male", "age": 64, "fare": 27.72},
    {"name": "Moubarek, Master. Gerios", "survived": 1, "pclass": 3, "sex": "male", "age": 7, "fare": 15.25},
    {"name": "Nye, Mrs. (Elizabeth Ramell)", "survived": 1, "pclass": 2, "sex": "female", "age": 29, "fare": 10.50},
    {"name": "Crease, Mr. Ernest James", "survived": 0, "pclass": 3, "sex": "male", "age": 19, "fare": 8.05},
    {"name": "Kink, Mr. Vincenz", "survived": 0, "pclass": 3, "sex": "male", "age": 26, "fare": 8.05},
    {"name": "Jenkin, Mr. Stephen Curnow", "survived": 0, "pclass": 2, "sex": "male", "age": 32, "fare": 10.50},
    {"name": "Goodwin, Miss. Lillian Amy", "survived": 0, "pclass": 3, "sex": "female", "age": 16, "fare": 46.90},
    {"name": "Hood, Mr. Ambrose Jr", "survived": 0, "pclass": 2, "sex": "male", "age": 21, "fare": 73.50},
    {"name": "Chronopoulos, Mr. Apostolos", "survived": 0, "pclass": 3, "sex": "male", "age": 26, "fare": 14.45},
    {"name": "Bing, Mr. Lee", "survived": 1, "pclass": 3, "sex": "male", "age": 32, "fare": 56.50},
    {"name": "Moen, Mr. Sigurd Hansen", "survived": 0, "pclass": 3, "sex": "male", "age": 25, "fare": 7.65},
    {"name": "Caldwell, Master. Alden Gates", "survived": 1, "pclass": 2, "sex": "male", "age": 1, "fare": 29.00},
    {"name": "Dowdell, Miss. Elizabeth", "survived": 1, "pclass": 3, "sex": "female", "age": 30, "fare": 12.48},
    {"name": "Waelens, Mr. Achille", "survived": 0, "pclass": 3, "sex": "male", "age": 22, "fare": 9.00},
    {"name": "Sheerlinck, Mr. Jan Baptist", "survived": 0, "pclass": 3, "sex": "male", "age": 29, "fare": 9.50},
    {"name": "Carrau, Mr. Francisco M", "survived": 0, "pclass": 1, "sex": "male", "age": 28, "fare": 47.10},
    {"name": "McDermott, Miss. Brigdet Delia", "survived": 1, "pclass": 3, "sex": "female", "age": 18, "fare": 7.79},
    {"name": "Slocovski, Mr. Selman Francis", "survived": 0, "pclass": 3, "sex": "male", "age": 20, "fare": 8.05},
    {"name": "Fortune, Miss. Mabel Helen", "survived": 1, "pclass": 1, "sex": "female", "age": 23, "fare": 263.00},
    {"name": "Celotti, Mr. Francesco", "survived": 0, "pclass": 3, "sex": "male", "age": 24, "fare": 8.05},
    {"name": "Christmann, Mr. Emil", "survived": 0, "pclass": 3, "sex": "male", "age": 29, "fare": 8.05},
    {"name": "Chaffee, Mr. Herbert Fuller", "survived": 0, "pclass": 1, "sex": "male", "age": 46, "fare": 61.18},
    {"name": "Dean, Master. Bertram Vere", "survived": 1, "pclass": 3, "sex": "male", "age": 1, "fare": 20.58},
    {"name": "Coxon, Mr. Daniel", "survived": 0, "pclass": 3, "sex": "male", "age": 59, "fare": 7.25},
    {"name": "Shorney, Mr. Charles Joseph", "survived": 0, "pclass": 3, "sex": "male", "age": 22, "fare": 8.05},
    {"name": "Goldschmidt, Mr. George B", "survived": 0, "pclass": 1, "sex": "male", "age": 71, "fare": 34.65},
    {"name": "Greenfield, Mr. William Bertram", "survived": 1, "pclass": 1, "sex": "male", "age": 23, "fare": 63.36},
    {"name": "Doling, Miss. Elsie", "survived": 1, "pclass": 2, "sex": "female", "age": 18, "fare": 23.00},
    {"name": "Kantor, Mr. Sinai", "survived": 0, "pclass": 2, "sex": "male", "age": 34, "fare": 26.00},
    {"name": "Petranec, Miss. Matilda", "survived": 0, "pclass": 3, "sex": "female", "age": 28, "fare": 7.90},
    {"name": "Gustafsson, Mr. Anders Vilhelm", "survived": 0, "pclass": 3, "sex": "male", "age": 37, "fare": 7.93},
    {"name": "Johansson, Mr. Karl Johan", "survived": 0, "pclass": 3, "sex": "male", "age": 31, "fare": 7.78},
    {"name": "Long, Mr. Milton Clyde", "survived": 0, "pclass": 1, "sex": "male", "age": 29, "fare": 30.00},
    {"name": "Meo, Mr. Alfonzo", "survived": 0, "pclass": 3, "sex": "male", "age": 55, "fare": 8.05},
    {"name": "Mernagh, Mr. Robert", "survived": 0, "pclass": 3, "sex": "male", "age": 26, "fare": 7.75},
    {"name": "Penasco y Castellana, Mr. Victor de Satode", "survived": 0, "pclass": 1, "sex": "male", "age": 18, "fare": 108.90},
    {"name": "Dean, Mr. Bertram Frank", "survived": 0, "pclass": 3, "sex": "male", "age": 26, "fare": 20.58},
    {"name": "Coxon, Mrs. Daniel (Mary)", "survived": 1, "pclass": 3, "sex": "female", "age": 52, "fare": 7.25},
    {"name": "Skoog, Mr. Wilhelm", "survived": 0, "pclass": 3, "sex": "male", "age": 40, "fare": 27.90},
    {"name": "Somerton, Mr. Francis William", "survived": 0, "pclass": 3, "sex": "male", "age": 30, "fare": 8.05},
    {"name": "Lurette, Miss. Elise", "survived": 1, "pclass": 1, "sex": "female", "age": 58, "fare": 146.52},
    {"name": "Mellinger, Miss. Madeleine Violet", "survived": 1, "pclass": 2, "sex": "female", "age": 13, "fare": 19.50},
    {"name": "Healy, Miss. Hanora 'Nora'", "survived": 1, "pclass": 3, "sex": "female", "age": 22, "fare": 7.75}
]

# %% [markdown]
# total number of passengers

# %%
total_number_passenger=len(passengers)
total_number_passenger
# Out:
# 100

# %% [markdown]
# total number of male passengers

# %%
male_passenger=[p for p in passengers if p["sex"]=="male"]

print(len(male_passenger))
# Out:
# 60

# %% [markdown]
# total number of female passengers

# %%
female_passenger=[p for p in passengers if p["sex"]=="female"]

print("female passgers count",len(female_passenger))
# Out:
# female passgers count 40

# %% [markdown]
# survived passengers

# %%
survived_passenger=[p for p in passengers if p["survived"]==1]

print(len(survived_passenger))
# Out:
# 40

# %% [markdown]
# first class

# %%
first_class=[p["name"] for p in passengers if p["pclass"]==1]

print(first_class)
# Out:
# ['Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'McCarthy, Mr. Timothy J', 'Bonnell, Miss. Elizabeth', 'Sloper, Mr. William Thompson', 'Fortune, Mr. Charles Alexander', 'Uruchurtu, Don. Manuel E', 'Spencer, Mrs. William Augustus (Marie Eugenie)', 'Meyer, Mr. Edgar Joseph', 'Holverson, Mr. Alexander Oskar', 'Harper, Mrs. Henry Sleeper (Myna Haxtun)', 'Ostby, Mr. Engelhart Cornelius', 'Icard, Miss. Amelie', 'Harris, Mr. Henry Birkhardt', 'Stewart, Mr. Albert A', 'Carrau, Mr. Francisco M', 'Fortune, Miss. Mabel Helen', 'Chaffee, Mr. Herbert Fuller', 'Goldschmidt, Mr. George B', 'Greenfield, Mr. William Bertram', 'Long, Mr. Milton Clyde', 'Penasco y Castellana, Mr. Victor de Satode', 'Lurette, Miss. Elise']

# %% [markdown]
# young passengers

# %%
young_passengers=[p["name"] for p in passengers if p["age"]<10]

print(young_passengers)

print(len(young_passengers))
# Out:
# ['Palsson, Master. Gosta Leonard', 'Sandstrom, Miss. Marguerite Rut', 'Rice, Master. Eugene', 'Palsson, Miss. Torborg Danira', 'Laroche, Miss. Simonne Marie Anne Andree', 'Panula, Master. Juha Niilo', 'West, Miss. Constance Mirium', 'Skoog, Master. Harald', 'Moubarek, Master. Gerios', 'Caldwell, Master. Alden Gates', 'Dean, Master. Bertram Vere']
# 11

# %% [markdown]
# survived rate of gender

# %%
female_survived=(p["name"] for p in passengers if p["survived"]==1 and p["sex"]=="female")


male_survived=(p["name"] for p in passengers if p["survived"]==1 and p["sex"]=="male")

print(female_survived)
print(male_survived)
