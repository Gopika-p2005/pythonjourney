# %% [markdown]
# ### file write operation

# %%
fw=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\student.txt","w")

names=["jithin","hari","vishnu","shyam","renjin"]

for n in names:

    fw.write(n+"\n")

fw.close()

# %% [markdown]
# ### file read and write

# %%
fr=open("r")

fw_malayalam=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\movie_Malayalam.txt","w")

fw_kanada=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\movie_kanada.txt","w")

for line in fr:

    line=line.rstrip("\n")

    title,language=line.split(',')

if language==malaya
