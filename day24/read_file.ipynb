# %% [markdown]
# ### reading from files

# %%
fr=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\greeting.txt","r")

for line in fr:

    print(line)

# %%
fr=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\employes.txt","r")

for line in fr:

    print(line)

# %% [markdown]
# ### restaurend menu

# %%
fr=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\restaurant.txt","r")

orders=[line.rstrip("\n") for line in fr ]

order_count={r:orders.count(r) for r in orders }

print(order_count)

# %% [markdown]
# ### movies

# %%
fr=open("C:\\Users\\Acer\\Desktop\\python works\\day24\\movies.txt","r")

movie=[line.rstrip("\n") for line in fr]

print(movie)

# %%
movie_count={m:movie.count(m) for m in movie }

print(movie_count)
# Out:
# {'The Dark Knight': 2, 'Inception': 2, 'Pulp Fiction': 2, 'The Shawshank Redemption': 2, 'Interstellar': 2, 'Spirited Away': 2, 'The Matrix': 2, 'Parasite': 2, 'Gladiator': 2, 'The Godfather': 2, 'Avatar': 2, 'Titanic': 2, 'Jurassic Park': 2, 'Star Wars: A New Hope': 2, 'The Lion King': 2, 'Whiplash': 2, 'La La Land': 2, 'Arrival': 2, 'Blade Runner 2049': 1, 'The Prestige': 1, 'Mad Max: Fury Road': 1, 'Spider-Man: Into the Spider-Verse': 2, 'Everything Everywhere All at Once': 1, 'Get Out': 2, 'Dune': 2, 'The Grand Budapest Hotel': 1, 'The Wolf of Wall Street': 2, 'Shutter Island': 2, 'Inglourious Basterds': 1, 'Django Unchained': 1, 'Coco': 1, 'Toy Story': 1, 'Finding Nemo': 1, 'Monsters, Inc.': 1, 'Ratatouille': 1, 'Your Name': 1, 'Princess Mononoke': 1, "Howl's Moving Castle": 1, 'My Neighbor Totoro': 1, 'Goodfellas': 1, 'Fight Club': 1, 'Se7en': 1, 'The Silence of the Lambs': 1, 'Forrest Gump': 1, 'The Green Mile': 1, 'Saving Private Ryan': 1, "Schindler's List": 1, 'The Departed
# ...
